# %% [markdown]
# # title
# ## subtitle
# ### Heading
# #### Sub Heading

# %% [markdown]
# # title
# ## heading
# ### subheading

# %% [markdown]
# # title

# %% [markdown]
# ***
# 1. git
# 2. python
# 3. numpy
# ***

# %% [markdown]
# - this is a normal text
# - this is italic *
# - this is bold *

# %% [markdown]
# *hi
# **hello

# %% [markdown]
# *hi*
# **hello**

# %% [markdown]
# [Google](https://www.google.com)

# %% [markdown]
# ```hi
#    welcome```
# `hello`

# %% [markdown]
# - ![](data:image/jpeg;base64,...)
